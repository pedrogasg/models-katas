# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrogasg/models-katas/blob/master/FashionMnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from tensorflow import keras
from keras.datasets import mnist
from keras.datasets import fashion_mnist
# Out:
# Using TensorFlow backend.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
# Out:
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 4us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 2s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-labels-idx1-ubyte.gz
# 8192/5148 [===============================================] - 0s 0us/step
# Downloading data from http://fashion-mnist.s3-website.eu-central-1.amazonaws.com/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 1s 0us/step

# %%
unique, counts = np.unique(y_train, return_counts=True)
print('Train labels: ', dict(zip(unique, counts)))
# Out:
# Train labels:  {0: 6000, 1: 6000, 2: 6000, 3: 6000, 4: 6000, 5: 6000, 6: 6000, 7: 6000, 8: 6000, 9: 6000}

# %%
unique, counts = np.unique(y_test, return_counts=True)
print('Test labels: ', dict(zip(unique, counts)))
# Out:
# Test labels:  {0: 1000, 1: 1000, 2: 1000, 3: 1000, 4: 1000, 5: 1000, 6: 1000, 7: 1000, 8: 1000, 9: 1000}

# %%
indexes = np.random.randint(0, x_train.shape[0], size=25)
images = x_train[indexes]
labels = y_train[indexes]

# %%
plt.figure(figsize=(5,5))
for i in range(len(indexes)):
  plt.subplot(5, 5, i + 1)
  image = images[i]
  plt.imshow(image, cmap='gray')
  plt.axis('off')

plt.show()

# %%
num_labels = len(np.unique(y_train))

# %%
from keras.utils import to_categorical, plot_model
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
image_shape = x_train.shape

# %%
from keras.models import Model
from keras.layers import Activation, Dense, Dropout, Input
from keras.layers import Conv2D, MaxPooling2D, Flatten

# %%
x_train = np.reshape(x_train,[-1, image_shape[1], image_shape[2], 1])
x_test = np.reshape(x_test,[-1, image_shape[1], image_shape[2], 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
input_shape = (image_shape[1], image_shape[2], 1)
batch_size = 128
kernel_size = 3
filters = 64
dropout = 0.3

# %%
inputs = Input(shape=input_shape)
x = inputs
x = Conv2D(filters=filters,
        kernel_size=kernel_size,
        activation='relu',
        input_shape=input_shape)(x)
x = MaxPooling2D()(x)
x = Conv2D(filters=filters,
        kernel_size=kernel_size,
        activation='relu')(x)
x = MaxPooling2D()(x)
x = Conv2D(filters=filters,
        kernel_size=kernel_size,
        activation='relu')(x)
x = Flatten()(x)
x = Dropout(dropout)(x)
outputs = Dense(num_labels, activation='softmax')(x)
model = Model(inputs=inputs, outputs=outputs)
model.summary()
plot_model(model, show_shapes=True)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 28, 28, 1)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 26, 26, 64)        640
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 13, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 11, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 3, 64)          36928
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 576)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 576)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5770
# =================================================================
# Total params: 80,266
# Trainable params: 80,266
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=20, batch_size=batch_size)
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 9s 148us/step - loss: 0.6499 - accuracy: 0.7621
# Epoch 2/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.4168 - accuracy: 0.8489
# Epoch 3/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.3602 - accuracy: 0.8697
# Epoch 4/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.3253 - accuracy: 0.8823
# Epoch 5/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.3026 - accuracy: 0.8903
# Epoch 6/20
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.2877 - accuracy: 0.8957
# Epoch 7/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.2719 - accuracy: 0.9008
# Epoch 8/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.2579 - accuracy: 0.9068
# Epoch 9/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.2474 - accuracy: 0.9090
# Epoch 10/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.2367 - accuracy: 0.9131
# Epoch 11/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.2294 - accuracy: 0.9154
# Epoch 12/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.2196 - accuracy: 0.9184
# Epoch 13/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.2103 - accuracy: 0.9217
# Epoch 14/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.2046 - accuracy: 0.9243
# Epoch 15/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.1980 - accuracy: 0.9269
# Epoch 16/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.1904 - accuracy: 0.9294
# Epoch 17/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.1876 - accuracy: 0.9294
# Epoch 18/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.1777 - accuracy: 0.9339
# Epoch 19/20
# 60000/60000 [==============================] - 3s 43us/step - loss: 0.1738 - accuracy: 0.9358
# Epoch 20/20
# 60000/60000 [==============================] - 3s 44us/step - loss: 0.1684 - accuracy: 0.9365

# %%
ev, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 10000/10000 [==============================] - 0s 26us/step

# %%
print("\n Test accuracy: %.2f%%" % (100.0 * acc))
# Out:
#  Test accuracy: 91.18%

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, SimpleRNN

# %%
input_shape = (image_shape[1], image_shape[2])
batch_size = 128
units = 256
dropout = 0.2

# %%
x_train = np.reshape(x_train,[-1, image_shape[1], image_shape[2]])
x_test = np.reshape(x_test,[-1, image_shape[1], image_shape[2]])

# %%
inputs = Input(shape=input_shape)
x = inputs
x = SimpleRNN(units=units, dropout=dropout, input_shape=input_shape)(x)
outputs = Dense(num_labels, activation='softmax')(x)
model = Model(inputs=inputs, outputs=outputs)
model.summary()
plot_model(model, show_shapes=True)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 28, 28)            0
# _________________________________________________________________
# simple_rnn_1 (SimpleRNN)     (None, 256)               72960
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 75,530
# Trainable params: 75,530
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=20, batch_size=batch_size)
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 9s 144us/step - loss: 1.0009 - accuracy: 0.6388
# Epoch 2/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.6935 - accuracy: 0.7425
# Epoch 3/20
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.6153 - accuracy: 0.7720
# Epoch 4/20
# 60000/60000 [==============================] - 9s 145us/step - loss: 0.5767 - accuracy: 0.7856
# Epoch 5/20
# 60000/60000 [==============================] - 9s 149us/step - loss: 0.5397 - accuracy: 0.8012
# Epoch 6/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.5209 - accuracy: 0.8090
# Epoch 7/20
# 60000/60000 [==============================] - 9s 144us/step - loss: 0.5013 - accuracy: 0.8165
# Epoch 8/20
# 60000/60000 [==============================] - 8s 141us/step - loss: 0.4840 - accuracy: 0.8207
# Epoch 9/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.4716 - accuracy: 0.8262
# Epoch 10/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.4587 - accuracy: 0.8318
# Epoch 11/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.4513 - accuracy: 0.8332
# Epoch 12/20
# 60000/60000 [==============================] - 8s 141us/step - loss: 0.4413 - accuracy: 0.8366
# Epoch 13/20
# 60000/60000 [==============================] - 8s 141us/step - loss: 0.4350 - accuracy: 0.8395
# Epoch 14/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.4259 - accuracy: 0.8436
# Epoch 15/20
# 60000/60000 [==============================] - 9s 142us/step - loss: 0.4211 - accuracy: 0.8443
# Epoch 16/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.4174 - accuracy: 0.8464
# Epoch 17/20
# 60000/60000 [==============================] - 9s 144us/step - loss: 0.4098 - accuracy: 0.8496
# Epoch 18/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.4042 - accuracy: 0.8514
# Epoch 19/20
# 60000/60000 [==============================] - 8s 141us/step - loss: 0.4024 - accuracy: 0.8511
# Epoch 20/20
# 60000/60000 [==============================] - 9s 143us/step - loss: 0.3986 - accuracy: 0.8518

# %%
ev, acc = model.evaluate(x_test, y_test, batch_size=batch_size)
# Out:
# 10000/10000 [==============================] - 0s 35us/step

# %%
print("\nTest accuracy: %.1f%%" % (100.0 * acc))
# Out:
# Test accuracy: 85.8%

# %%
from keras.models import Model, Sequential
from keras.layers import Dense, Dropout, Input
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Flatten, concatenate

# %%
x_train = np.reshape(x_train,[-1, image_shape[1], image_shape[2], 1])
x_test = np.reshape(x_test,[-1,  image_shape[1], image_shape[2], 1])
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %%
input_shape = (image_shape[1], image_shape[2], 1)
batch_size = 32
kernel_size = 3
dropout = 0.4
n_filters = [32, 64, 128]

# %%
def convolutions(x, filters, dilation_rate=1):
  for filter in filters:
    x = Conv2D(filters=filter,
               kernel_size=kernel_size,
               padding='same',
               activation='relu',
               dilation_rate=dilation_rate)(x)
    x = Dropout(dropout)(x)
    x = MaxPooling2D()(x)
  return x

# %%
left_inputs = Input(shape=input_shape)
x1 = convolutions(left_inputs, n_filters)

right_inputs = Input(shape=input_shape)
x2 = convolutions(right_inputs, n_filters, 2)

x = concatenate([x1, x2])
x = Flatten()(x)
x = Dropout(dropout)(x)
outputs = Dense(num_labels, activation='softmax')(x)
model = Model([left_inputs, right_inputs], outputs)
model.summary()
plot_model(model, show_shapes=True)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 28, 28, 1)    0
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 32)   320         input_3[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 32)   320         input_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 28, 28, 32)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 28, 28, 32)   0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 32)   0           dropout_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 32)   0           dropout_5[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 14, 14, 64)   18496       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 14, 14, 64)   18496       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 14, 14, 64)   0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 14, 14, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 7, 7, 64)     0           dropout_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 7, 7, 64)     0           dropout_6[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 7, 7, 128)    73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 7, 7, 128)    73856       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 7, 7, 128)    0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 7, 7, 128)    0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 3, 3, 128)    0           dropout_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 3, 3, 128)    0           dropout_7[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 3, 3, 256)    0           max_pooling2d_5[0][0]
#                                                                  max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2304)         0           concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 2304)         0           flatten_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 10)           23050       dropout_8[0][0]
# ==================================================================================================
# Total params: 208,394
# Trainable params: 208,394
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# %%
model.fit([x_train, x_train],
          y_train,
          epochs=20,
          batch_size=batch_size)
# Out:
# Epoch 1/20
# 60000/60000 [==============================] - 14s 230us/step - loss: 0.8763 - accuracy: 0.6705
# Epoch 2/20
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.5973 - accuracy: 0.7765
# Epoch 3/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.5177 - accuracy: 0.8082
# Epoch 4/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.4806 - accuracy: 0.8249
# Epoch 5/20
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.4530 - accuracy: 0.8321
# Epoch 6/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.4397 - accuracy: 0.8375
# Epoch 7/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.4292 - accuracy: 0.8428
# Epoch 8/20
# 60000/60000 [==============================] - 13s 224us/step - loss: 0.4201 - accuracy: 0.8447
# Epoch 9/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.4110 - accuracy: 0.8482
# Epoch 10/20
# 60000/60000 [==============================] - 14s 226us/step - loss: 0.4023 - accuracy: 0.8513
# Epoch 11/20
# 60000/60000 [==============================] - 14s 229us/step - loss: 0.3986 - accuracy: 0.8536
# Epoch 12/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.3923 - accuracy: 0.8555
# Epoch 13/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.3880 - accuracy: 0.8595
# Epoch 14/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.3827 - accuracy: 0.8577
# Epoch 15/20
# 60000/60000 [==============================] - 13s 222us/step - loss: 0.3756 - accuracy: 0.8626
# Epoch 16/20
# 60000/60000 [==============================] - 13s 222us/step - loss: 0.3781 - accuracy: 0.8606
# Epoch 17/20
# 60000/60000 [==============================] - 13s 222us/step - loss: 0.3721 - accuracy: 0.8633
# Epoch 18/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.3680 - accuracy: 0.8650
# Epoch 19/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.3642 - accuracy: 0.8645
# Epoch 20/20
# 60000/60000 [==============================] - 13s 223us/step - loss: 0.3645 - accuracy: 0.8674

# %%
score = model.evaluate([x_test, x_test],
                       y_test,
                       batch_size=batch_size,
                       verbose=0)
print("\nTest accuracy: %.1f%%" % (100.0 * score[1]))
# Out:
# Test accuracy: 79.8%
